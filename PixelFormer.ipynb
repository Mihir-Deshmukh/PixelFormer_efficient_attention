# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/PixelFormer/PixelFormer/
# Out:
# /content/drive/MyDrive/PixelFormer/PixelFormer

# %%
# !pip install -U fvcore

# %% [markdown]
# Change Torch version

# %%
# !pip install torch==1.11.0+cu113 torchvision==0.12.0+cu113 torchaudio==0.11.0 --extra-index-url https://download.pytorch.org/whl/cu113

# %%
# !pip install matplotlib tqdm tensorboardX timm

# %%
# !pip install mmcv-full -f https://download.openmmlab.com/mmcv/dist/cu113/torch1.11.0/index.html

# %%
# !pip install einops

# %% [markdown]
# Training and Evaluation

# %%
# !python pixelformer/train.py configs/arguments_train_nyu.txt

# %%
# !python pixelformer/eval.py configs/arguments_eval_nyu.txt

# %%
# !python pixelformer/test.py configs/arguments_test_nyu.txt
